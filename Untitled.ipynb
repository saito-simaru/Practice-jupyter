# %%
# !pip install motmetrics
# !pip install opencv-python
import motmetrics as mm
import numpy as np
import cv2

# %%
image = cv2.imread("waterbottol.jpg")

# %%
from PIL import Image
# Out:
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 13.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/212.5 MB ? eta -:--:--
#     --------------------------------------- 3.7/212.5 MB 18.2 MB/s eta 0:00:12
#    - -------------------------------------- 7.6/212.5 MB 18.1 MB/s eta 0:00:12
#    -- ------------------------------------- 11.5/212.5 MB 18.5 MB/s eta 0:00:11
#    -- ------------------------------------- 14.7/212.5 MB 17.4 MB/s eta 0:00:12
#    --- ------------------------------------ 18.6/212.5 MB 17.5 MB/s eta 0:00:12
#    ---- ----------------------------------- 22.5/212.5 MB 17.8 MB/s eta 0:00:11
#    ---- ----------------------------------- 26.2/212.5 MB 17.7 MB/s eta 0:00:11
#    ----- ---------------------------------- 30.1/212.5 MB 17.9 MB/s eta 0:00:11
#    ------ --------------------------------- 33.8/212.5 MB 17.8 MB/s eta 0:00:11
# ...
